# %%
# !pip install streamlit
# !pip install pytubefix
# !pip install requests
# !pip install BeautifulSoup
# Out:
# Requirement already satisfied: streamlit in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (1.44.1)
# Requirement already satisfied: altair<6,>=4.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (2.2.5)
# Requirement already satisfied: packaging<25,>=20 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: pytubefix in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (8.12.3)
# Requirement already satisfied: requests in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages (from requests) (2025.1.31)
# Collecting BeautifulSoup
#   Using cached BeautifulSoup-3.2.2.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [7 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-5fx48374/beautifulsoup_e00af6455d5d4eb6aa43587156d9c164/setup.py", line 3
#           "You're trying to run a very old release of Beautiful Soup under Python 3. This will not work."<>"Please use Beautiful Soup 4, available through the pip package 'beautifulsoup4'."
#                                                                                                          ^^
#       SyntaxError: invalid syntax
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import streamlit as st
from pytubefix import YouTube
import requests
from bs4 import BeautifulSoup
import os
# Function to get video metadata
def scrape_youtube_video_details(video_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
    }
    try:
        response = requests.get(video_url, headers=headers)
        if response.status_code != 200:
            st.error(f"Failed to retrieve video page. Status code: {response.status_code}, Content: {response.text}")
        
        soup = BeautifulSoup(response.text, 'html.parser')
        title_tag = soup.find("meta", property="og:title")
        description_tag = soup.find("meta", property="og:description")
        thumbnail_tag = soup.find("meta", property="og:image")

        return {
            "title": title_tag["content"] if title_tag else "N/A",
            "description": description_tag["content"] if description_tag else "N/A",
            "thumbnail": thumbnail_tag["content"] if thumbnail_tag else ""
        }
    except Exception as e:
        return {"error": str(e)}

def download_youtube_video(video_url):
    try:
        yt = YouTube(video_url)
        
        # Get highest resolution video-only stream
        video_stream = yt.streams.filter(file_extension='mp4', only_video=True).order_by('resolution').desc().first()
        audio_stream = yt.streams.filter(only_audio=True).order_by('abr').desc().first()

        if not video_stream or not audio_stream:
            return "❌ Video or audio stream not found."

        video_file = video_stream.download(output_path="downloads/", filename_prefix="video_")
        audio_file = audio_stream.download(output_path="downloads/", filename_prefix="audio_")

        # Prepare output filename
        sanitized_title = "".join(c for c in yt.title if c.isalnum() or c in (' ', '.', '_')).rstrip()
        combined_file = f"downloads/{sanitized_title}_combined.mp4"

        # Combine using ffmpeg
        command = f"ffmpeg -y -i \"{video_file}\" -i \"{audio_file}\" -c:v copy -c:a aac \"{combined_file}\""
        os.system(command)

        # Cleanup
        os.remove(video_file)
        os.remove(audio_file)

        return combined_file

    except Exception as e:
        return f"❌ Error: {str(e)}"


# Streamlit App
st.set_page_config(page_title="YouTube Scraper & Downloader", layout="centered")
st.title("📽️ YouTube Scraper + Downloader (No API)")

# Add some styling
st.markdown(
    """
    <style>
    .stTextInput>div>div>input {
        background-color: #f0f4f8;
        border-radius: 10px;
        padding: 10px;
    }
    .stButton>button {
        background-color: #1E90FF;
        color: white;
        border-radius: 8px;
        font-size: 16px;
        padding: 10px;
        transition: background-color 0.3s;
    }
    .stButton>button:hover {
        background-color: #4169E1;
    }
    .stAlert {
        border-radius: 10px;
    }
    .stImage {
        border-radius: 10px;
        border: 5px solid #d3d3d3;
    }
    </style>
    """,
    unsafe_allow_html=True,
)

url = st.text_input("Enter YouTube Video URL")

col1, col2 = st.columns([2, 1])

with col1:
    if st.button("Scrape Video Info"):
        if "youtube.com/watch?v=" not in url:
            st.error("❌ Invalid YouTube URL.")
        else:
            st.info("🔍 Scraping video details...")
            video_data = scrape_youtube_video_details(url)

            if "error" in video_data:
                st.error(f"❌ {video_data['error']}")
            else:
                st.subheader("🎬 Video Title")
                st.write(video_data['title'])

                st.subheader("📝 Video Description")
                st.write(video_data['description'])

                if video_data['thumbnail']:
                    st.image(video_data['thumbnail'], caption="Video Thumbnail", width=400)

with col2:
    if st.button("Download Video"):
        if "youtube.com/watch?v=" not in url:
            st.error("❌ Invalid YouTube URL.")
        else:
            st.info("⬇️ Downloading video...")
            result = download_youtube_video(url)
            if "downloads/" in result:
                st.success("✅ Video downloaded successfully!")
                st.write(f"📂 File path: {result}")
            else:
                st.error(f"❌ Download failed: {result}")
# Out:
# 2025-04-23 18:47:22.522 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.522 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.560
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-04-23 18:47:22.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.564 Session state does not function when running a script without `streamlit run`
# 2025-04-23 18:47:22.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-23 18:47:22.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run /home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages/ipykernel_launcher.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://192.168.1.72:8502
#
# [IPKernelApp] ERROR | Unable to initialize signal:
# Traceback (most recent call last):
#   File "/home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in initialize
#     self.init_signal()
#   File "/home/talha/anaconda3/envs/Sigma2/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 545, in init_signal
#     signal.signal(signal.SIGINT, signal.SIG_IGN)
#   File "/home/talha/anaconda3/envs/Sigma2/lib/python3.12/signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: signal only works in main thread of the main interpreter
# ^C
